# %%
import requests
from datetime import datetime as dt
import base64
import json

MODELS_API_URL = "https://dafni-nims-api.secure.dafni.rl.ac.uk"
LOGIN_API_URL = "https://login.secure.dafni.rl.ac.uk"
DATA_UPLOAD_API_URL = "https://dafni-nid-api.secure.dafni.rl.ac.uk"
DISCOVERY_API_URL = "https://dafni-search-and-discovery-api.secure.dafni.rl.ac.uk"
DSS_API_URL = "https://dafni-dss-dssauth.secure.dafni.rl.ac.uk"

def process_jwt(jwt):
    claims = jwt.split('.')[1]
    jwt_bytes = claims.encode('utf-8') + b'=='
    message_bytes = base64.b64decode(jwt_bytes)
    message = message_bytes.decode('utf-8')
    json_dict = json.loads(message)

    return {
        'expiry': dt.fromtimestamp(json_dict['exp']),
        'user_id': json_dict['sub'],
        'jwt': 'JWT ' + jwt
    }

# %%
def get_dafni_jwt(user_name, password):
    post_response = requests.post(
        LOGIN_API_URL + '/login/',         
        json={"username": user_name, "password": password},
        headers={
            "Content-Type": "application/json",
        },
        allow_redirects=False
    )
    post_response.raise_for_status()
    jwt = post_response.cookies['__Secure-dafnijwt']
    return process_jwt(jwt)

# %%
user_name = 'ian-roper'
pwd = '9a1c&iKHWz2b!v$6o'
users_jwt = get_dafni_jwt(user_name, pwd)

# %%
def get_users_models(jwt_dict):
    models_request = requests.get(
        MODELS_API_URL + '/models/',
        headers={
            "Content-Type": "application/json",
            "authorization": jwt_dict['jwt']
        },
        allow_redirects=False
    )
    models_request.raise_for_status()
    return models_request.json()

# %%
get_users_models(users_jwt)
# Out:
# [{'id': '9de4ad50-fd98-4def-9bfc-39378854e6a1',
#   'name': '5G Model',
#   'owner': 'ad36a410-d7d1-431f-af90-ff6fe56adc9b',
#   'summary': 'A model to estimate the demand for and cost of rolling out 5G across the UK for a variety of different population and demand scenarios..',
#   'description': 'Mobile communication is key to delivering smart infrastructure and cities, as well as providing an alternative to fixed broadband connections that reach beyond the expected future mobile bandwidth requirements as new technologies, such as 5G, are rolled out.\n\nThe Principle Investigator for this Pilot is Edward Oughton from the University of Oxford who developed both the fixed broadband and mobile communication models. Advanced network planning involves a combination of engineering, computer science and economics, in order to establish cost-efficient digital connectivity strategies delivering new capacity and coverage. Such an approach provides analytics which support investment decisions.',
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2019-07-17T13:33:13.751682Z',
#   'publication_date': '2020-04-02T09:12:25.989915Z',
#   'container': 'reg.dafni.rl.ac.uk/pilots/models/mobile-model/nims',
#   'container_version': 'nims',
#   'ingest_completed_date': None,
#   'version_tags': ['latest'],
#   'version_message': '',
#   'file_reference': '57fe6c9f-d8d4-41eb-b0cd-86222b961b9b',
#   'parent_model': 'd7a6e414-c6c2-4ba8-82e1-729b25dd4ed1',
#   'auth': {'asset_id': '9de4ad50-fd98-4def-9bfc-39378854e6a1',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}},
#  {'id': '0b4b0d0a-5b05-4e14-b382-9a5c9082315b',
#   'name': 'COVID-19 CovidSim Model',
#   'owner': 'd3144f90-b0b6-4ce3-9c31-fef745c97eac',
#   'summary': 'CovidSim models the transmission dynamics and severity of COVID-19 infections throughout a spatially and socially structured population over time.\n',
#   'description': "The CovidSim model from Imperial College London is a spatial model that models the transmission of COVID-19.\nThe model begins by dividing a country into cells and microcells (9x9 microcells to a cell). People live in households located in cells and are allocated according to the population density data (given in input files).\nPeople are assigned to places (institutions such as households, offices, schools etc...) that have a geographical location. People don't move once assigned to a place. Instead, the simulation employs spatial mixing probability distributions that control the probability that people in cell X will infect people in cell Y located in another spatial region.\nInfections are spread via 3 different transmission mechanisms: household (between family members), place infections (at work) and spatial infections (whilst travelling around).\nRead more here: https://github.com/mrc-ide/covid-sim/blob/master/docs/model-overview.md\n",
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2020-08-14T15:20:45.024964Z',
#   'publication_date': '2020-08-14T15:20:45.024979Z',
#   'container': 'covid-sim',
#   'container_version': '0b4b0d0a-5b05-4e14-b382-9a5c9082315b',
#   'ingest_completed_date': '2020-08-14T15:20:59.113209Z',
#   'version_tags': [],
#   'version_message': '',
#   'file_reference': '0b4b0d0a-5b05-4e14-b382-9a5c9082315b',
#   'parent_model': '71bf9e61-4977-40e1-b85e-7301350c5c0e',
#   'auth': {'asset_id': '0b4b0d0a-5b05-4e14-b382-9a5c9082315b',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}},
#  {'id': 'ef4b22c8-63be-4b53-ba7c-c1cf301774b2',
#   'name': 'Non-Spatial Housing Model',
#   'owner': '66224be7-7fe0-43bc-b2d8-5fa838b6d19a',
#   'summary': 'A simulation of the overall UK housing market using agents to represent households, banks, etc., with the aim of modelling market fluctuations.',
#   'description': 'The non-spatial hosing model was developed by Adrian Carro at the Oxford Institute of New Economic Thinking. This version of the software assumes a single market and does not include spatial variations of house prices.\n\nAgents are used to represent various players in the market including separate households who look to buy and rent homes as well as some who invest in Buy-to-let (BTL) properties. One aim of the simulation is to see how policy on BTL investor influences the over volatility of the housing market. The user is able to adjust various input parameters that control the simulation to see what effect these have of the output of the model.\n\nOutputs include the Sale House price index, Rental House price index and related measures such as the number of buy-to-let properties in the market.',
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2019-07-17T13:33:13.780431Z',
#   'publication_date': '2020-04-02T09:12:26.044216Z',
#   'container': 'reg.dafni.rl.ac.uk/pilots/models/ns-housing-model/nims',
#   'container_version': 'nims',
#   'ingest_completed_date': None,
#   'version_tags': ['latest'],
#   'version_message': '',
#   'file_reference': 'ebce28b3-a2d9-473c-8e55-8d020886849a',
#   'parent_model': 'a7bf128e-836f-4840-ab8a-cbd10fa6338b',
#   'auth': {'asset_id': 'ef4b22c8-63be-4b53-ba7c-c1cf301774b2',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}},
#  {'id': '399cdaac-aab6-494d-870a-66de8a4217bb',
#   'name': 'Spatial Housing Model',
#   'owner': 'cfd1bd98-e615-45bc-8245-005d4a52037d',
#   'summary': 'An agent based model of the UK housing market allowing for the interaction between different regions in terms of travel costs and time.',
#   'description': 'This is a spatial agent-based model of the UK housing market written by the Institute of New Economic Thinking (INET) at the Oxford Martin School, University of Oxford. It is based on a previous non-spatial model developed by INET in collaboration with the Bank of England. A detailed description of this initial non-spatial model can be found as a Staff Working Paper of the Bank of England.\n\nThe spatial model, while keeping the same agents as in the non-spatial version (owner-occupiers, renters, buy-to-let investors, a private bank, a central bank, a construction sector, and a government), incorporates a number of spatial features with their corresponding agent behaviours. Namely, households have to decide where to bid for housing given a certain spatial distribution of prices and commuting costs. These decisions, in turn, feed back into the market mechanism, possibly modifying the spatial distribution of prices.',
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2019-07-17T13:33:13.791513Z',
#   'publication_date': '2020-04-02T09:12:26.073327Z',
#   'container': 'reg.dafni.rl.ac.uk/pilots/models/sp-housing-model/nims',
#   'container_version': 'nims',
#   'ingest_completed_date': None,
#   'version_tags': ['latest'],
#   'version_message': '',
#   'file_reference': '4c886857-b626-4959-ba05-2237f6664008',
#   'parent_model': '8e3e4244-270a-4a96-b18f-af116751b919',
#   'auth': {'asset_id': '399cdaac-aab6-494d-870a-66de8a4217bb',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}},
#  {'id': 'd0942631-158c-4cd2-a75f-ec7ec5798381',
#   'name': 'SIMIM - Spatial Interaction Models of Internal Migration',
#   'owner': 'c52fd8b1-611d-43de-a591-72c521129061',
#   'summary': 'A model to predict the flow of people between Local Authority Districts (LAD) in the UK given a change in jobs, housing and gross value added in areas surrounding that LAD.',
#   'description': 'This package aims to build a flexible custom population projection generation tool based on spatial interaction models of internal migration within the UK (probably GB only). The tool is intended to be used to model the impact of large and long-term infrastructure changes on population distribution and growth.\n\nThe rationale is to take an official population projection (baseline or variant), internal migration data, and additional official figures for factors that may govern migration (employment, housing, GVA etc). The next step is to construct a spatial interaction model of internal migration from this data that meets some (arbitrary) goodness-of-fit criteria.\n\nFollowing this, a scenario must be invented that captures some change or changes given by example a future infrastructure project, for example by increasing the housing stock and/or jobs in a specific region. By reapplying the model to the original input data with the scenario applied, a modified migration O-D matrix is generated.\n\nFinally, the change to the O-D matrix can be applied to the original population projection to create a custom variant. The nature of the model means that localised changes have a global impact - so the new variant projection applies to the whole country.',
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2019-07-17T13:33:13.802193Z',
#   'publication_date': '2020-04-02T09:12:26.098649Z',
#   'container': 'reg.dafni.rl.ac.uk/pilots/models/simim/nims',
#   'container_version': 'nims',
#   'ingest_completed_date': None,
#   'version_tags': ['latest'],
#   'version_message': '',
#   'file_reference': '8fc9b749-de98-49f2-ab2e-34f0533e4f3f',
#   'parent_model': '6b1793ca-da20-4d45-9318-bfe7abcc631a',
#   'auth': {'asset_id': 'd0942631-158c-4cd2-a75f-ec7ec5798381',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}},
#  {'id': 'a2dc91ea-c243-4232-8d2e-f951fc5f8248',
#   'name': 'Transform',
#   'owner': '1819bf83-1b62-43d5-900f-6a636b1856f7',
#   'summary': 'Perform a basic statistical analysis reduction.',
#   'description': 'Perform a basic statistical analysis reduction.',
#   'kind': 'M',
#   'visibility': 'P',
#   'status': 'L',
#   'creation_date': '2019-07-17T13:33:13.812683Z',
#   'publication_date': '2020-04-02T09:12:26.130620Z',
#   'container': 'reg.dafni.rl.ac.uk/dafni/nims/transform',
#   'container_version': 'master',
#   'ingest_completed_date': None,
#   'version_tags': ['latest'],
#   'version_message': '',
#   'file_reference': '81a70e77-9260-49ef-8ae1-0eafadb5d5b0',
#   'parent_model': '7f2e4bc3-6f48-48ac-aafd-0e8a4378e0c8',
#   'auth': {'asset_id': 'a2dc91ea-c243-4232-8d2e-f951fc5f8248',
#    'reason': 'Accessed as part of the Public group',
#    'view': True,
#    'read': True,
#    'update': False,
#    'destroy': False}}]
